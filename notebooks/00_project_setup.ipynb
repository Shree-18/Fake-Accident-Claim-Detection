# %% [markdown]
# ### Project Overview

# %% [raw]
# # Phase 0 — Project Setup & Planning
#
# ## Project Title
# Fake Accident Claim Detection System
#
# ## Objective
# Automatically detect fake or fraudulent accident claims using ML and real-time data sources (weather, location, image checks).
#
# ## Inputs
# - Date
# - Time
# - Location
# - Description
# - Image
#
# ## Outputs
# - Risk Score (0–1)
# - Classification: Genuine / Suspicious / Fraudulent

# %% [markdown]
# ### Complete Step-By-Step Roadmap

# %% [raw]
# Perfect 👏 — that’s exactly the right next step!
# Let’s make this very clear and **practical** — below is your **complete step-by-step roadmap** for building your **“Fake Accident Claim Detection System”** from start to finish, using **only free tools, public datasets, and APIs**.
#
# This roadmap assumes you have about **2–3 months (final semester)** and want something **real-world, demo-ready, and impactful**.
#
# ---
#
# ## 🚀 PHASE 0 — Project Setup & Planning (Week 1)
#
# **Goal:** Define scope, collect sample data, set up environment.
#
# ### ✅ Tasks:
#
# 1. **Define what your system will do:**
#
#    * Input: Claim details (date, time, place, description, image)
#    * Output: Risk score (Genuine / Suspicious / Fraudulent)
#
# 2. **Setup Tools & Environment**
#
#    * Python 3.10+
#    * Jupyter Notebook / VS Code
#    * Flask / Django (for web interface)
#    * Libraries:
#      `pandas`, `numpy`, `scikit-learn`, `flask`, `requests`, `beautifulsoup4`,
#      `matplotlib`, `OpenCV`, `imagehash`, `textblob`, `exifread`
#
# 3. **Data Collection**
#
#    * Download accident or insurance fraud datasets from:
#
#      * [Kaggle: “Insurance Claim Fraud Detection Dataset”](https://www.kaggle.com/datasets)
#      * [data.gov.in: Road accident statistics]
#    * Create your own small dataset with fields like:
#      `Claim_ID, Date, Time, Location, Description, Image_URL, Weather_Reported, Actual_Weather, Is_Fraud`
#
# 4. **Version Control:**
#
#    * Use GitHub for your project repo (important for report submission).
#
# ---
#
# ## ⚙️ PHASE 1 — Backend & Data Processing (Weeks 2–3)
#
# **Goal:** Build backend and connect external APIs to verify claim data.
#
# ### ✅ Tasks:
#
# 1. **Connect OpenWeatherMap API**
#
#    * Fetch weather for a given location and date/time.
#    * Compare with claimed weather.
#    * Example check:
#
#      ```python
#      if claim_weather != actual_weather:
#          flag += 1
#      ```
#
# 2. **Connect Google Maps / OpenStreetMap**
#
#    * Reverse geocode GPS coordinates → get city/road name.
#    * Check if location is a valid road or suspicious area.
#
# 3. **Text Preprocessing (NLP)**
#
#    * Clean and tokenize claim descriptions.
#    * Extract keywords like “rain”, “brake”, “skid”, “collision”.
#    * Use `TF-IDF` or `BERT embeddings` to vectorize text.
#
# 4. **Store Data**
#
#    * Use SQLite/PostgreSQL or just CSV initially.
#
# ---
#
# ## 🧠 PHASE 2 — Machine Learning Model (Weeks 4–6)
#
# **Goal:** Train ML model to classify claims as Genuine / Fraudulent.
#
# ### ✅ Tasks:
#
# 1. **Feature Engineering**
#
#    * Combine textual features (from claim description)
#    * API features (weather match, location validity)
#    * Metadata (time of day, previous claim count)
#
# 2. **Model Building**
#
#    * Try ML models:
#
#      * Logistic Regression
#      * Random Forest
#      * XGBoost (best for tabular data)
#    * Train and evaluate with metrics:
#
#      * Accuracy
#      * Precision/Recall
#      * Confusion Matrix
#
# 3. **Model Optimization**
#
#    * Use GridSearchCV or RandomizedSearchCV.
#    * Save final model as `fraud_model.pkl`.
#
# 4. **Explainability**
#
#    * Use SHAP or LIME to visualize “why” a claim was flagged.
#
# ---
#
# ## 🖼️ PHASE 3 — Image & Evidence Verification (Weeks 6–8)
#
# **Goal:** Add image and metadata verification for realism.
#
# ### ✅ Tasks:
#
# 1. **Extract EXIF Data from Uploaded Image**
#
#    * Extract timestamp, GPS coordinates.
#    * Compare with claimed data.
#
# 2. **Detect Image Reuse**
#
#    * Use `imagehash` to check if similar image exists in past claims.
#
# 3. **Optional: AI Damage Detection**
#
#    * Use a small pretrained CNN (MobileNet) to classify image as:
#      “Minor damage”, “Major damage”, “No visible damage”.
#
# ---
#
# ## 🧩 PHASE 4 — Integration & Dashboard (Weeks 8–10)
#
# **Goal:** Combine all modules into one smooth system.
#
# ### ✅ Tasks:
#
# 1. **Flask / Django Backend**
#
#    * Route: `/submit_claim` → receives form data.
#    * Process input → run ML + API checks → return risk score.
#
# 2. **Frontend**
#
#    * Simple HTML/CSS + JavaScript or React.
#    * Dashboard:
#
#      * Input form for new claim
#      * Risk score display (color-coded)
#      * Table for claim history with fraud probability
#      * Charts: fraud trends, claim categories
#
# 3. **Visualization**
#
#    * Use `Chart.js` or `Plotly` for:
#
#      * % of fraudulent claims
#      * Most suspicious locations
#      * API mismatch causes
#
# ---
#
# ## 🌐 PHASE 5 — Real-Time Enhancements (Weeks 10–11)
#
# **Goal:** Add real-time verification layer.
#
# ### ✅ Tasks:
#
# 1. **Live Social Media Check**
#
#    * Use `NewsData.io` or `Tweepy` to check if local sources report any accident.
#    * Add “social validation score” to the model.
#
# 2. **Time-based Validation**
#
#    * Reject claims for future timestamps or unusual hours (e.g., 3 AM empty road claims).
#
# ---
#
# ## 🧾 PHASE 6 — Documentation & Report (Weeks 11–12)
#
# **Goal:** Finalize and prepare for submission/demo.
#
# ### ✅ Tasks:
#
# 1. **Project Report Sections:**
#
#    * Abstract
#    * Introduction
#    * Problem Statement
#    * Literature Review
#    * Methodology (with architecture diagram)
#    * Implementation (with screenshots)
#    * Results & Discussion
#    * Future Scope
#    * References
#
# 2. **Create PowerPoint Presentation**
#
#    * Problem → Solution → Workflow → Results → Live Demo
#
# 3. **Prepare Live Demo**
#
#    * Show real claim input → real API fetch → risk score output.
#    * Bonus: Show image verification.
#
# ---
#
# ## 🧠 Tech Stack Summary
#
# | Component     | Technology                               |
# | ------------- | ---------------------------------------- |
# | Language      | Python                                   |
# | ML Libraries  | scikit-learn, XGBoost                    |
# | Web Framework | Flask or Django                          |
# | Frontend      | HTML/CSS/JS, Chart.js                    |
# | APIs          | OpenWeatherMap, Google Maps, NewsData.io |
# | DB            | SQLite / PostgreSQL                      |
# | Tools         | GitHub, Jupyter, VS Code                 |
#
# ---
#
# ## 🏁 Expected Final Demo Flow
#
# 1. You open a simple web page and input:
#
#    * Claim details (location, date, description)
#    * Upload an image
# 2. System fetches:
#
#    * Live weather & location data
#    * Compares it with claim info
#    * Runs trained ML model
# 3. Output:
#
#    * Fraud probability score (e.g. 0.87)
#    * Reasons: “Weather mismatch”, “Duplicate image”, “Odd time”
# 4. Dashboard shows historical data and risk trends.
#
# ---
#
# ## 🌟 Bonus (If Time Allows)
#
# * Add **user authentication** (admin/agent login).
# * Integrate **email alert** for high-risk claims using `smtplib`.
# * Deploy on **Render / Vercel / Heroku** (free hosting).
#
# ---
#
# Would you like me to now create a **visual architecture diagram + file structure blueprint** (so you know exactly what folders, files, and code modules to create for this project)?
# That will be your “project skeleton” to start coding right away.

# %% [markdown]
# ### Recommendation for Your Project

# %% [raw]
# Excellent question 💡 — this is a common dilemma for ML & final-year projects!
# Let’s do a **side-by-side comparison** so you can pick what fits *your* workflow best 👇
#
# ---
#
# ## ⚖️ **JupyterLab vs VS Code (for your project)**
#
# | Feature                    | 🧪 **JupyterLab**                                     | 💻 **VS Code**                                     |
# | -------------------------- | ----------------------------------------------------- | -------------------------------------------------- |
# | **Best for**               | Data exploration, model building, EDA                 | Full-stack development (Flask app, APIs, frontend) |
# | **Interface**              | Browser-based, cell-by-cell                           | Full IDE with project-wide view                    |
# | **Ease of Learning**       | Very beginner-friendly                                | Slightly more setup needed                         |
# | **Data Visualization**     | Excellent (inline graphs, live outputs)               | Requires toggling plots or using Jupyter extension |
# | **Documentation Style**    | Markdown + code in one notebook (perfect for reports) | Plain scripts; documentation separate              |
# | **Speed / Debugging**      | Great for iterative testing                           | Great for debugging larger apps                    |
# | **Integration with Flask** | Indirect (export models)                              | Direct (you can run `app.py` and debug routes)     |
# | **Ideal Phase**            | Phase 1–3: Data, ML, Testing                          | Phase 4–5: Integration, Deployment, UI             |
#
# ---
#
# ## 🧭 **Recommendation for *Your* Project**
#
# Since your project involves both **Machine Learning** and **Web Development (Flask)**:
#
# ✅ **Use both — strategically:**
#
# ### **Phase 1–3 (Data → Model Training)**
#
# 👉 **Use JupyterLab**
#
# * Easier for data cleaning, visualizations, experimentation.
# * You can document each step for your final report.
# * Notebooks like:
#
#   * `01_data_cleaning.ipynb`
#   * `02_model_training.ipynb`
#
# Then export your final trained model:
#
# ```python
# import joblib
# joblib.dump(model, 'models/fraud_detection_model.pkl')
# ```
#
# ---
#
# ### **Phase 4–5 (Integration → Final UI)**
#
# 👉 **Switch to VS Code**
#
# * Better for writing and debugging your Flask backend (`app.py`).
# * Easier to handle multiple files (HTML, JS, CSS, utils/ modules).
# * You can run:
#
#   ```bash
#   python app.py
#   ```
#
#   and test your web app directly.
#
# ---
#
# ## 🧰 **Best Setup Combo (for you)**
#
# | Task                       | Recommended Tool         |
# | -------------------------- | ------------------------ |
# | Data Cleaning & EDA        | **JupyterLab**           |
# | Model Training             | **JupyterLab**           |
# | Flask Integration          | **VS Code**              |
# | UI (HTML, CSS, JS)         | **VS Code**              |
# | Final Testing & Deployment | **VS Code**              |
# | Report Screenshots         | **JupyterLab notebooks** |
#
# ---
#
# ## 🧩 **Final Verdict**
#
# > 🏆 **Best workflow:**
# > **JupyterLab for experimentation → VS Code for deployment**
#
# This combo is the same used by professional data scientists & AI engineers.
#
# ---
#
# Would you like me to give you a **clear step-by-step workflow plan** (like “Phase 1 in Jupyter, then move to VS Code at Phase 4, with specific checkpoints”)?
# It’ll show you *exactly when and how* to switch tools efficiently.

# %% [markdown]
# ### Check Python Version

# %%
# !python --version
# Out:
# Python 3.10.19

# %%
# Core Libraries
# !pip install pandas numpy scikit-learn flask requests beautifulsoup4 matplotlib joblib

# Additional Tools for Later Phases
# !pip install opencv-python imagehash textblob exifread
# Out:
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/39.0 MB 9.8 MB/s eta 0:00:04
#    --- ------------------------------------ 3.4/39.0 MB 7.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.2/39.0 MB 6.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.5/39.0 MB 6.3 MB/s eta 0:00:06
#    ------ --------------------------------- 6.8/39.0 MB 6.4 MB/s eta 0:00:06
#    -------- ------------------------------- 8.7/39.0 MB 6.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.5/39.0 MB 6.8 MB/s eta 0:00:05
#    ------------ --------------------------- 11.8/39.0 MB 6.8 MB/s eta 0:00:05
#    ------------- -------------------------- 13.1/39.0 MB 6.6 MB/s eta 0:00:04
#    -------------- ------------------------- 14.4/39.0 MB 6.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.0/39.0 MB 6.7 MB/s eta 0:00:04
# ...

# %% [markdown]
# ## 📁 Project Folder Structure Setup
# We'll create the main folders for organizing our files and code.

# %%
import os

folders = [
    "dataset", "models", "templates", "static",
    "utils", "notebooks"
]

for f in folders:
    os.makedirs(f, exist_ok=True)
print("✅ Project structure created successfully!")
# Out:
# ✅ Project structure created successfully!

# %%
import os
print("📂 Current Folder Contents:")
print(os.listdir())
# Out:
# 📂 Current Folder Contents:
# ['.ipynb_checkpoints', '00_project_setup.ipynb', 'dataset', 'models', 'notebooks', 'static', 'templates', 'utils']

# %% [markdown]
# ## 🧾 Create Initial Sample Dataset
# We'll create a small CSV file with sample claims for early testing.

# %%
import pandas as pd

data = {
    "Claim_ID": ["C001", "C002", "C003", "C004"],
    "Date": ["2024-05-03", "2024-06-12", "2024-07-01", "2024-08-22"],
    "Time": ["14:30", "20:10", "09:00", "18:45"],
    "Location": ["Mumbai", "Delhi", "Pune", "Chennai"],
    "Description": [
        "Car hit divider due to heavy rain",
        "Bike slipped near signal during clear weather",
        "Truck collision on foggy morning",
        "Car accident claimed to happen in storm"
    ],
    "Image_URL": ["img1.jpg", "img2.jpg", "img3.jpg", "img4.jpg"],
    "Weather_Reported": ["Rain", "Clear", "Fog", "Storm"],
    "Actual_Weather": ["Rain", "Clear", "Clear", "Clear"],
    "Is_Fraud": [0, 1, 0, 1]
}

df = pd.DataFrame(data)
df.to_csv("dataset/sample_claims.csv", index=False)
print("✅ Sample dataset created at dataset/sample_claims.csv")
df.head()
# Out:
# ✅ Sample dataset created at dataset/sample_claims.csv
#   Claim_ID        Date   Time Location  \
# 0     C001  2024-05-03  14:30   Mumbai
# 1     C002  2024-06-12  20:10    Delhi
# 2     C003  2024-07-01  09:00     Pune
# 3     C004  2024-08-22  18:45  Chennai
#
#                                      Description Image_URL Weather_Reported  \
# 0              Car hit divider due to heavy rain  img1.jpg             Rain
# 1  Bike slipped near signal during clear weather  img2.jpg            Clear
# 2               Truck collision on foggy morning  img3.jpg              Fog
# 3        Car accident claimed to happen in storm  img4.jpg            Storm
#
#   Actual_Weather  Is_Fraud
# 0           Rain         0
# 1          Clear         1
# 2          Clear         0
# 3          Clear         1

# %% [markdown]
# ## 🌐 API Keys (to be added in future phases)
#
# - [ ] OpenWeatherMap → WEATHER_API_KEY
# - [ ] NewsData.io → NEWS_API_KEY
# - [ ] OpenStreetMap Nominatim → For location verification

# %% [markdown]
# ## 🧭 Version Control Setup (GitHub)
#
# Use these commands in **Anaconda Prompt** (not inside Jupyter):
#
# ```bash
# git init
# git add .
# git commit -m "Phase 0: initial setup and dataset creation"
# git branch -M main
# git remote add origin https://github.com/<username>/Fake-Accident-Claim-Detection.git
# git push -u origin main
